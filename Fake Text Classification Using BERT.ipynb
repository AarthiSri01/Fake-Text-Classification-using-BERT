# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 33.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 17.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 64.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 76.8 MB/s eta 0:00:00
# ...

# %%
from transformers import BertTokenizer, BertForSequenceClassification
import torch

# Load pre-trained model and tokenizer
model_name = 'bert-base-uncased'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertForSequenceClassification.from_pretrained(model_name)

# Define classes
labels = ["legitimate", "fake"]

def identify_fake_message(text):
    inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True)
    with torch.no_grad():
        outputs = model(**inputs)
        predictions = torch.argmax(outputs.logits, dim=1)
    return labels[predictions]

def main():
    text = input("Enter a message: ")
    result = identify_fake_message(text)
    print(f"The message is classified as: {result}")

if __name__ == "__main__":
    main()
# Out:
# ...
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Enter a message: hey you won lottery click on the below link
# The message is classified as: fake

# %%
from transformers import BertTokenizer, BertForSequenceClassification
import torch
import re
from urllib.parse import urlparse

# Load pre-trained model and tokenizer
model_name = 'bert-base-uncased'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertForSequenceClassification.from_pretrained(model_name)

# Define classes
labels = ["legitimate", "fake"]

def identify_text(text):
    inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True)
    with torch.no_grad():
        outputs = model(**inputs)
        predictions = torch.argmax(outputs.logits, dim=1)
    return labels[predictions]

def analyze_url(url):
    # Perform URL analysis here
    return "legitimate"  # Placeholder result for demonstration

def identify_message(message):
    text_result = identify_text(message)

    urls = re.findall(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', message)
    url_results = {url: analyze_url(url) for url in urls}

    return text_result, url_results

def main():
    message = input("Enter a message: ")
    text_result, url_results = identify_message(message)
    print(f"Text classified as: {text_result}")
    for url, result in url_results.items():
        print(f"URL: {url} is classified as: {result}")

if __name__ == "__main__":
    main()
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Enter a message: http://newphoneoffer.com/
# Text classified as: fake
# URL: http://newphoneoffer.com/ is classified as: legitimate
